# %% [markdown]
# # Introduction
#
# Every pass play has some combination of routes

# %% [markdown]
# # Data
#
# ## Feature Engineering

# %% [markdown]
# # Model

# %% [markdown]
# # Results

# %% [markdown]
# # Conclusions

# %% [markdown]
# # Appendix

# %% [markdown]
# ![test](https://drive.google.com/uc?export=view&id=1--CGjZFPQFwW43jhndq6pVedURL-UBJU)

# %% [markdown]
# ![test](https://drive.google.com/uc?export=view&id=1u2C12dTZgJDSR1p7rU3XvE3iEV5D6s9Y)

# %% [markdown]
# ![image alt text](https://drive.google.com/file/d/1u2C12dTZgJDSR1p7rU3XvE3iEV5D6s9Y/view?usp=drive_link)

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
cur_path = "/content/drive/MyDrive/BDB 2025/"
os.chdir(cur_path)
# !pwd

from IPython.display import Video

Video("./visuals/animation_notrail.mp4",embed=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
